# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('supply_chain_data.csv', delimiter=',')

# %% [markdown]
# # Info

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.tail()
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 95     haircare  SKU95  77.903927            65                      672
# 96    cosmetics  SKU96  24.423131            29                      324
# 97     haircare  SKU97   3.526111            56                       62
# 98     skincare  SKU98  19.754605            43                      913
# 99     haircare  SKU99  68.517833            17                      627
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 95        7386.363944               Unknown            15          14
# 96        7698.424766            Non-binary            67           2
# 97        4370.916580                  Male            46          19
# 98        8525.952560                Female            53           1
# 99        9185.185829               Unknown            55           8
#
#     Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %%
df.shape
# Out:
# (100, 24)

# %%
df.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Graficos
#
#
#
# 1. Product type - Tipo de produto
# 2. SKU - SKU (Unidade de Manutenção de Estoque)
# 3. Price - Preço
# 4. Availability - Disponibilidade
# 5. Number of products sold - Número de produtos vendidos
# 6. Revenue generated - Receita gerada
# 7. Customer demographics - Demografia dos clientes
# 8. Stock levels - Níveis de estoque
# 9. Lead times - Prazo de entrega
# 10. Order quantities - Quantidade de pedidos
# 11. Shipping times - Tempo de envio
# 12. Shipping carriers - Transportadoras
# 13. Shipping costs - Custos de envio
# 14. Supplier name - Nome do fornecedor
# 15. Location - Localização
# 16. Lead time - Prazo de entrega
# 17. Production volumes - Volume de produção
# 18. Manufacturing lead time - Tempo de fabricação
# 19. Manufacturing costs - Custos de fabricação
# 20. Inspection results - Resultados da inspeção
# 21. Defect rates - Taxa de defeitos
# 22. Transportation modes - Modos de transporte
# 23. Routes - Rotas
# 24. Costs - Custos

# %%
soma_order_quantities = df['Order quantities'].sum()
print('Soma da quantidade de pedidos: ',soma_order_quantities)
# Out:
# Soma da quantidade de pedidos:  4922

# %%
soma_revenue_generated = df['Revenue generated'].sum()
print(f'Soma do valor de vendas: {soma_revenue_generated:.2f}')
# Out:
# Soma do valor de vendas: 577604.82

# %%
soma_Availability = df['Availability'].sum()
print(f'Soma da disponibilidade: {soma_Availability:.2f}')
# Out:
# Soma da disponibilidade: 4840.00

# %%
soma_Stock_levels = df['Stock levels'].sum()
print(f'Soma do estoque: {soma_Stock_levels:.2f}')
# Out:
# Soma do estoque: 4777.00

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='Product type', y='Price', data=df)
plt.title('Distribuição de Preços por Tipo de Produto')
plt.xlabel('Tipo de Produto')
plt.ylabel('Preço')
plt.show()

# %%
media = df.groupby('Product type')['Price'].mean()
print(media)
# Out:
# Product type
# cosmetics    57.361058
# haircare     46.014279
# skincare     47.259329
# Name: Price, dtype: float64

# %%
grouped_df = df.groupby('Product type')['Revenue generated'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Product type', y='Revenue generated', data=grouped_df, palette='Greys', hue='Product type', dodge=False)

plt.title('Receita gerada por tipo de produto')
plt.xlabel('Tipo de Produto')
plt.ylabel('Receita gerada')
# Out:
# Text(0, 0.5, 'Receita gerada')

# %%
# Gráfico de barras mostrando o total de produtos vendidos ("Number of products sold") para cada tipo de produto.
# Number of products sold
# Product type

grouped_df = df.groupby('Product type')['Number of products sold'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Product type', y='Number of products sold', data=grouped_df, palette='Reds', hue='Product type', dodge=False)

plt.title('Número de produtos vendidos por tipo de produto')
plt.xlabel('Tipo de Produto')
plt.ylabel('Número de produtos vendidos')
# Out:
# Text(0, 0.5, 'Número de produtos vendidos')

# %%
# Gráfico de barras mostrando a disponibilidade média 
# ("Availability") de produtos para cada tipo de produto.
# Availability
grouped_df_availability = df.groupby('Product type')['Availability'].mean().reset_index()
plt.figure(figsize=(10, 6))

sns.barplot(x='Product type', y='Availability', data=grouped_df_availability, palette='Oranges', hue='Product type', dodge=False)
plt.title('Disponibilidade média por tipo de produto')
plt.xlabel('Tipo de Produto')
plt.ylabel('Disponibilidade média')
# Out:
# Text(0, 0.5, 'Disponibilidade média')

# %%
# FORMA ALTERNATIVA:
plt.figure(figsize=(12, 8))
sns.barplot(x='Product type', y='Availability', data=df)
plt.title('Disponibilidade média por tipo de produto')
plt.xlabel('Tipo de Produto')
plt.ylabel('Disponibilidade média')
# Out:
# Text(0, 0.5, 'Disponibilidade média')

# %%
# Análise de Demografia dos Clientes:
# Um gráfico de pizza mostrando a distribuição demográfica dos clientes ("Customer demographics").
# Customer demographics
Dados_demográficos_do_cliente = df['Customer demographics'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(Dados_demográficos_do_cliente, labels=Dados_demográficos_do_cliente.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribuição Demográfica dos Clientes')
# Out:
# Text(0.5, 1.0, 'Distribuição Demográfica dos Clientes')

# %%
# Análise de Demografia dos Clientes:
# Um gráfico de pizza mostrando a distribuição demográfica dos clientes ("Customer demographics").
# Customer demographics
Dados_demográficos_do_cliente = df['Customer demographics'].value_counts().drop('Unknown', errors='ignore')

plt.figure(figsize=(8, 8))
plt.pie(Dados_demográficos_do_cliente, labels=Dados_demográficos_do_cliente.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribuição Demográfica dos Clientes')
# Out:
# Text(0.5, 1.0, 'Distribuição Demográfica dos Clientes')

# %%
# Níveis de Estoque por Tipo de Produto:
# Um gráfico de barras para mostrar os níveis de estoque 
# ("Stock levels") para cada tipo de produto.
# O que precisa?  Product type & Stock levels - Níveis de estoque

grouped_df = df.groupby('Product type')['Stock levels'].sum().reset_index()
plt.figure(figsize=(10, 8))
sns.barplot(x='Product type', y='Stock levels', data=grouped_df, palette='Purples', hue='Product type', dodge=False)

plt.title('Níveis de Estoque por Tipo de Produto')
plt.xlabel('Tipo de Produto')
plt.ylabel('Níveis de Estoque')
# Out:
# Text(0, 0.5, 'Níveis de Estoque')

# %%
# Relação entre Tempo de Espera e Quantidade de Pedidos:
# Um gráfico de dispersão (scatter plot) para mostrar a relação 
# entre os tempos de espera ("Lead times") e as quantidades de pedidos 
# ("Order quantities").
# Lead times - Prazo de entrega
# Order quantities - Quantidade de pedidos

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Lead times', y='Order quantities', data=df, alpha=1)

plt.title('Relação entre Lead Times e Quantidades de Pedidos')
plt.xlabel('Prazos de entrega (dias)')
plt.ylabel('Quantidades do pedido')
# Out:
# Text(0, 0.5, 'Quantidades do pedido')

# %%
# Custos de Envio por Transportadora:
# custos médios de envio ("Shipping costs") para cada transportadora ("Shipping carriers").
# Shipping costs - Custos de envio
# Shipping carriers - Transportadoras


grouped_df_shipping = df.groupby('Shipping carriers')['Shipping costs'].mean().reset_index()
plt.figure(figsize=(12, 8))
sns.barplot(x='Shipping carriers', y='Shipping costs', data=grouped_df_shipping, palette='viridis', hue='Shipping carriers', dodge=False)

plt.title('Custos médios de envio por transportadora')
plt.xlabel('Transportadoras')
plt.ylabel('Custos médios de envio')
# Out:
# Text(0, 0.5, 'Custos médios de envio')

# %%
df.loc[:,['Shipping carriers','Shipping costs']]
# Out:
#    Shipping carriers  Shipping costs
# 0          Carrier B        2.956572
# 1          Carrier A        9.716575
# 2          Carrier B        8.054479
# 3          Carrier C        1.729569
# 4          Carrier A        3.890548
# ..               ...             ...
# 95         Carrier B        8.630339
# 96         Carrier C        5.352878
# 97         Carrier A        7.904846
# 98         Carrier B        1.409801
# 99         Carrier B        1.311024
#
# [100 rows x 2 columns]

# %%
# Custos de Envio por Transportadora:
# custos médios de envio ("Shipping costs") para cada transportadora ("Shipping carriers").
# Shipping costs - Custos de envio
# Shipping carriers - Transportadoras


grouped_df_shipping = df.groupby('Shipping carriers')['Shipping costs'].sum().reset_index()
plt.figure(figsize=(12, 8))
sns.barplot(x='Shipping carriers', y='Shipping costs', data=grouped_df_shipping, palette='viridis', hue='Shipping carriers', dodge=False)

plt.title('Custos médios de envio por transportadora')
plt.xlabel('Transportadoras')
plt.ylabel('Custos médios de envio')
# Out:
# Text(0, 0.5, 'Custos médios de envio')

# %%
df.loc[:,['Supplier name','Production volumes']]
# Out:
#    Supplier name  Production volumes
# 0     Supplier 3                 215
# 1     Supplier 3                 517
# 2     Supplier 1                 971
# 3     Supplier 5                 937
# 4     Supplier 1                 414
# ..           ...                 ...
# 95    Supplier 4                 450
# 96    Supplier 3                 648
# 97    Supplier 4                 535
# 98    Supplier 5                 581
# 99    Supplier 2                 921
#
# [100 rows x 2 columns]

# %%
# Tempos de Produção por Fornecedor:
# tempos de produção ("Production volumes" e "Manufacturing lead time") 
# para cada fornecedor ("Supplier name").
# Supplier name - Nome do fornecedor
# Production volumes - Volume de produção
# Manufacturing lead time - Tempo de fabricação


grupo_df = df.groupby('Supplier name')['Production volumes'].sum().reset_index()
plt.figure(figsize=(10, 8))
sns.barplot(x='Supplier name', y='Production volumes', data=grupo_df, palette='Purples', hue='Supplier name', dodge=False)

plt.title('Nome do fornecedor por Volume de produção')
plt.xlabel('Nome do fornecedor')
plt.ylabel('Volume de produção')
# Out:
# Text(0, 0.5, 'Volume de produção')

# %%
# Tempos de Produção por Fornecedor:
# tempos de produção ("Production volumes" e "Manufacturing lead time") 
# para cada fornecedor ("Supplier name").
# Supplier name - Nome do fornecedor
# Production volumes - Volume de produção
# Manufacturing lead time - Tempo de fabricação


grupo_df = df.groupby('Supplier name')['Manufacturing lead time'].sum().reset_index()
plt.figure(figsize=(10, 8))
sns.barplot(x='Supplier name', y='Manufacturing lead time', data=grupo_df, palette='Purples', hue='Supplier name', dodge=False)

plt.title('Nome do fornecedor por Tempo de fabricação')
plt.xlabel('Nome do fornecedor')
plt.ylabel('Tempo de fabricação')
# Out:
# Text(0, 0.5, 'Tempo de fabricação')

# %%
# Number of products sold by Location

grouped_df = df.groupby('Location')['Number of products sold'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Location', y='Number of products sold', data=grouped_df, palette='Greens', hue='Location', dodge=False)
# Out:
# <Axes: xlabel='Location', ylabel='Number of products sold'>

# %%
df.loc[:,['Location']].drop_duplicates()
# Out:
#     Location
# 0     Mumbai
# 3    Kolkata
# 4      Delhi
# 5  Bangalore
# 9    Chennai

# %% [markdown]
# # Estimating regression fits

# %% [markdown]
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
sns.regplot(x= 'Price', y= 'Revenue generated', data= df)
# Out:
# <Axes: xlabel='Price', ylabel='Revenue generated'>

# %%
sns.regplot(x= 'Price', y= 'Shipping costs', data= df)
# Out:
# <Axes: xlabel='Price', ylabel='Shipping costs'>

# %%
sns.regplot(x= 'Price', y= 'Revenue generated', data= df)
# Out:
# <Axes: xlabel='Price', ylabel='Revenue generated'>

# %%
# Manufacturing lead time
# Defection rate
sns.regplot(x= 'Lead time', y= 'Manufacturing lead time', data= df)
# Out:
# <Axes: xlabel='Lead time', ylabel='Manufacturing lead time'>
